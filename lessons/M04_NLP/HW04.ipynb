# %% [markdown]
# # HW 04
#
# Charlie Perez (cwp5xyj)
#
# ## Part 1: setting things up

# %%
import pandas as pd
import numpy as np
from glob import glob
import re
import nltk
import plotly_express as px
import configparser

# %%
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']

# %%
source_files = f'{data_home}/eliot-set'
data_prefix = 'eliot'

# %%
local_lib = '/home/cwp5xyj/Documents/MSDS/DS5001/repo-main/lessons/lib'
import sys
import os
sys.path.append(os.path.abspath(local_lib))

# %%
local_lib
# Out:
# '/home/cwp5xyj/Documents/MSDS/DS5001/repo-main/lessons/lib'

# %%
from textparser import TextParser

# %%
# define OHCO patterns

roman = '[IVXLCM]+'
caps = "[A-Z';, -]+"

# after some searching, I think this should work
ohco_pat_list = [
    (507, rf"^(?:Chapter\s+{roman}|Epilogue)\.?\s*$"),
    (145,  rf"^(?:PRELUDE|CHAPTER|FINALE)"),
    (6688, rf"^\s*Chapter\s+{roman}\.?\s*$")
]

# %%
source_file_list = sorted(glob(f"{source_files}/*.*"))
source_file_list
# Out:
# ['/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_ADAM_BEDE-pg507.txt',
#  '/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_MIDDLEMARCH-pg145.txt',
#  '/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_THE_MILL_ON_THE_FLOSS-pg6688.txt']

# %%
book_data = []
for source_file_path in source_file_list:
    book_id = int(source_file_path.split('-')[-1].split('.')[0].replace('pg',''))
    book_title = source_file_path.split('/')[-1].split('-')[0].replace('_', ' ')
    book_data.append((book_id, source_file_path, book_title))

book_data
# Out:
# [(507,
#   '/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_ADAM_BEDE-pg507.txt',
#   'ELIOT GEORGE ADAM BEDE'),
#  (145,
#   '/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_MIDDLEMARCH-pg145.txt',
#   'ELIOT GEORGE MIDDLEMARCH'),
#  (6688,
#   '/home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_THE_MILL_ON_THE_FLOSS-pg6688.txt',
#   'ELIOT GEORGE THE MILL ON THE FLOSS')]

# %%
LIB = pd.DataFrame(book_data, columns=['book_id','source_file_path','raw_title'])\
    .set_index('book_id').sort_index()
LIB
# Out:
#                                           source_file_path  \
# book_id
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...
#
#                                   raw_title
# book_id
# 145                ELIOT GEORGE MIDDLEMARCH
# 507                  ELIOT GEORGE ADAM BEDE
# 6688     ELIOT GEORGE THE MILL ON THE FLOSS

# %%
try:
    LIB['author'] = LIB.raw_title.apply(lambda x: ', '.join(x.split()[:2]))
    LIB['title'] = LIB.raw_title.apply(lambda x: ' '.join(x.split()[2:]))
    LIB = LIB.drop('raw_title', axis=1)
except AttributeError:
    pass

# %%
LIB
# Out:
#                                           source_file_path         author  \
# book_id
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
#
#                          title
# book_id
# 145                MIDDLEMARCH
# 507                  ADAM BEDE
# 6688     THE MILL ON THE FLOSS

# %%
LIB['chap_regex'] = LIB.index.map(pd.Series({x[0]:x[1] for x in ohco_pat_list}))
LIB
# Out:
#                                           source_file_path         author  \
# book_id
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
#
#                          title                                chap_regex
# book_id
# 145                MIDDLEMARCH               ^(?:PRELUDE|CHAPTER|FINALE)
# 507                  ADAM BEDE  ^(?:Chapter\s+[IVXLCM]+|Epilogue)\.?\s*$
# 6688     THE MILL ON THE FLOSS            ^\s*Chapter\s+[IVXLCM]+\.?\s*$

# %%
def tokenize_collection(LIB):

    clip_pats = [
        r"\*\*\*\s*START OF",
        r"\*\*\*\s*END OF"
    ]
    

    books = []
    for book_id in LIB.index:
        if book_id == 507:
            clip_pats = [
                r"^(?:Epilogue)$",
                r"\*\*\*\s*END OF"
            ]
        else:
            clip_pats = [
                r"\*\*\*\s*START OF",
                r"\*\*\*\s*END OF"
            ]
        # Announce
        print("Tokenizing", book_id, LIB.loc[book_id].title)

        # Define vars
        chap_regex = LIB.loc[book_id].chap_regex
        ohco_pats = [('chap', chap_regex, 'm')]
        src_file_path = LIB.loc[book_id].source_file_path

        # Create object
        text = TextParser(src_file_path, ohco_pats=ohco_pats, clip_pats=clip_pats, use_nltk=True)
        # text = TextImporter(src_file_path, ohco_pats=ohco_pats, clip_pats=clip_pats) 

        # Define parameters
        text.verbose = True
        text.strip_hyphens = True
        text.strip_whitespace = True

        # Parse
        text.import_source().parse_tokens();

        # Name things
        text.TOKENS['book_id'] = book_id
        text.TOKENS = text.TOKENS.reset_index().set_index(['book_id'] + text.OHCO)

        # Add to list
        books.append(text.TOKENS)
        
    # Combine into a single dataframe
    CORPUS = pd.concat(books).sort_index()

    # Clean up
    del(books)
    del(text)
        
    print("Done")
        
    return CORPUS

# %%
CORPUS = tokenize_collection(LIB)
# Out:
# Tokenizing 145 MIDDLEMARCH
# Importing  /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_MIDDLEMARCH-pg145.txt
# Clipping text
# Parsing OHCO level 0 chap_id by milestone ^(?:PRELUDE|CHAPTER|FINALE)
# line_str chap_str
# Index(['chap_str'], dtype='object')
# Parsing OHCO level 1 para_num by delimitter \n\n
# Parsing OHCO level 2 sent_num by NLTK model
# Parsing OHCO level 3 token_num by NLTK model
# Tokenizing 507 ADAM BEDE
# Importing  /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_ADAM_BEDE-pg507.txt
# Clipping text
# Parsing OHCO level 0 chap_id by milestone ^(?:Chapter\s+[IVXLCM]+|Epilogue)\.?\s*$
# line_str chap_str
# Index(['chap_str'], dtype='object')
# Parsing OHCO level 1 para_num by delimitter \n\n
# Parsing OHCO level 2 sent_num by NLTK model
# Parsing OHCO level 3 token_num by NLTK model
# Tokenizing 6688 THE MILL ON THE FLOSS
# Importing  /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot-set/ELIOT_GEORGE_THE_MILL_ON_THE_FLOSS-pg6688.txt
# Clipping text
# Parsing OHCO level 0 chap_id by milestone ^\s*Chapter\s+[IVXLCM]+\.?\s*$
# line_str chap_str
# Index(['chap_str'], dtype='object')
# Parsing OHCO level 1 para_num by delimitter \n\n
# Parsing OHCO level 2 sent_num by NLTK model
# Parsing OHCO level 3 token_num by NLTK model
# Done

# %%
CORPUS.head()
# Out:
#                                                 pos_tuple  pos token_str  \
# book_id chap_id para_num sent_num token_num
# 145     1       1        0        0             (Who, WP)   WP       Who
#                                   1           (that, WDT)  WDT      that
#                                   2          (cares, VBZ)  VBZ     cares
#                                   3            (much, RB)   RB      much
#                                   4              (to, TO)   TO        to
#
#                                             term_str
# book_id chap_id para_num sent_num token_num
# 145     1       1        0        0              who
#                                   1             that
#                                   2            cares
#                                   3             much
#                                   4               to

# %% [markdown]
# This looks like it was successful, I'm just not totally sure what the best way to check my work here is.

# %%
CORPUS.tail()
# Out:
#                                                    pos_tuple  pos  token_str  \
# book_id chap_id para_num sent_num token_num
# 6688    58      69       0        2              (death, NN)   NN      death
#                                   3              (they, PRP)  PRP       they
#                                   4              (were, VBD)  VBD       were
#                                   5                (not, RB)   RB        not
#                                   6          (divided.”, JJ)   JJ  divided.”
#
#                                             term_str
# book_id chap_id para_num sent_num token_num
# 6688    58      69       0        2            death
#                                   3             they
#                                   4             were
#                                   5              not
#                                   6          divided

# %%
CORPUS.index[400000] # just to get something from the middle
# Out:
# (507, 18, 81, 6, 18)

# %% [markdown]
# Feels totally acceptable to me.

# %%
LIB['book_len'] = CORPUS.groupby('book_id').term_str.count()
LIB.sort_values('book_len')
# Out:
#                                           source_file_path         author  \
# book_id
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
#
#                          title                                chap_regex  \
# book_id
# 6688     THE MILL ON THE FLOSS            ^\s*Chapter\s+[IVXLCM]+\.?\s*$
# 507                  ADAM BEDE  ^(?:Chapter\s+[IVXLCM]+|Epilogue)\.?\s*$
# 145                MIDDLEMARCH               ^(?:PRELUDE|CHAPTER|FINALE)
#
#          book_len
# book_id
# 6688       207461
# 507        215403
# 145        317805

# %%
LIB['n_chaps'] = CORPUS.reset_index()[['book_id','chap_id']]\
    .drop_duplicates()\
    .groupby('book_id').chap_id.count()
LIB.sort_values('n_chaps')
# Out:
#                                           source_file_path         author  \
# book_id
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
#
#                          title                                chap_regex  \
# book_id
# 507                  ADAM BEDE  ^(?:Chapter\s+[IVXLCM]+|Epilogue)\.?\s*$
# 6688     THE MILL ON THE FLOSS            ^\s*Chapter\s+[IVXLCM]+\.?\s*$
# 145                MIDDLEMARCH               ^(?:PRELUDE|CHAPTER|FINALE)
#
#          book_len  n_chaps
# book_id
# 507        215403       56
# 6688       207461       58
# 145        317805       88

# %% [markdown]
# Yessssss fixed the problem with *Adam Bede*. That's so so awesome yay

# %%
chapter_lengths = CORPUS.groupby(['book_id', 'chap_id']).size()
chapter_lengths.sort_values().head()
# Out:
# book_id  chap_id
# 507      47         343
# 145      1          501
#          80         855
# 6688     1          898
# 507      55         970
# dtype: int64

# %%
CORPUS[CORPUS.term_str == '']
# Out:
#                                               pos_tuple  pos token_str  \
# book_id chap_id para_num sent_num token_num
# 145     5       46       1        0             (…, NN)   NN         …
#         6       0        0        39           (…, NNP)  NNP         …
#         30      33       5        0            ():, VB)   VB        ):
#         39      55       4        8            (…, NNP)  NNP         …
#         43      9        2        17            (&, CC)   CC         &
#         59      21       3        0            ();, NN)   NN        );
#                 53       1        0            ();, IN)   IN        );
#         72      3        1        0           (;”, NNS)  NNS        ;”
#         88      4        0        26            (&, CC)   CC         &
# 507     21      11       2        68         ((&), NNP)  NNP       (&)
# 6688    7       53       3        26            (&, CC)   CC         &
#         25      2        13       17            (&, CC)   CC         &
#                 12       0        27            (&, CC)   CC         &
#         26      6        0        14            (&, CC)   CC         &
#         27      3        3        11            (&, CC)   CC         &
#                          4        41            (&, CC)   CC         &
#         34      115      0        56            (&, CC)   CC         &
#         47      55       0        40            (&, CC)   CC         &
#         52      18       5        0            (),, NN)   NN        ),
#         55      1        5        0            (),, NN)   NN        ),
#
#                                             term_str
# book_id chap_id para_num sent_num token_num
# 145     5       46       1        0
#         6       0        0        39
#         30      33       5        0
#         39      55       4        8
#         43      9        2        17
#         59      21       3        0
#                 53       1        0
#         72      3        1        0
#         88      4        0        26
# 507     21      11       2        68
# 6688    7       53       3        26
#         25      2        13       17
#                 12       0        27
#         26      6        0        14
#         27      3        3        11
#                          4        41
#         34      115      0        56
#         47      55       0        40
#         52      18       5        0
#         55      1        5        0

# %%
CORPUS = CORPUS[CORPUS.term_str != '']

# %%
CORPUS['pos_group'] = CORPUS.pos.str[:2]
CORPUS.head()
# Out:
#                                                 pos_tuple  pos token_str  \
# book_id chap_id para_num sent_num token_num
# 145     1       1        0        0             (Who, WP)   WP       Who
#                                   1           (that, WDT)  WDT      that
#                                   2          (cares, VBZ)  VBZ     cares
#                                   3            (much, RB)   RB      much
#                                   4              (to, TO)   TO        to
#
#                                             term_str pos_group
# book_id chap_id para_num sent_num token_num
# 145     1       1        0        0              who        WP
#                                   1             that        WD
#                                   2            cares        VB
#                                   3             much        RB
#                                   4               to        TO

# %%
# vocabulary time

VOCAB = CORPUS.term_str.value_counts().to_frame('n').sort_index()
VOCAB.index.name = 'term_str'
VOCAB['n_chars'] = VOCAB.index.str.len()
VOCAB['p'] = VOCAB.n / VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)

VOCAB.head(10)
# Out:
#           n  n_chars         p         i
# term_str
# 1         1        1  0.000001  19.49843
# 1790      1        4  0.000001  19.49843
# 1799      2        4  0.000003  18.49843
# 1801more  1        8  0.000001  19.49843
# 1807      1        4  0.000001  19.49843
# 1825      1        4  0.000001  19.49843
# 1826      1        4  0.000001  19.49843
# 1828      1        4  0.000001  19.49843
# 1829      2        4  0.000003  18.49843
# 1831      1        4  0.000001  19.49843

# %%
# part of speech maxxing

VOCAB['max_pos'] = CORPUS[['term_str','pos']].value_counts().unstack(fill_value=0).idxmax(1)
VOCAB['max_pos_group'] = CORPUS[['term_str','pos_group']].value_counts().unstack(fill_value=0).idxmax(1)

VOCAB['n_pos_group'] = CORPUS[['term_str','pos_group']].value_counts().unstack().count(1)
VOCAB['cat_pos_group'] = CORPUS[['term_str','pos_group']].value_counts().to_frame('n').reset_index()\
    .groupby('term_str').pos_group.apply(lambda x: set(x))

VOCAB['n_pos'] = CORPUS[['term_str','pos']].value_counts().unstack().count(1)
VOCAB['cat_pos'] = CORPUS[['term_str','pos']].value_counts().to_frame('n').reset_index()\
    .groupby('term_str').pos.apply(lambda x: set(x))

VOCAB.head()
# Out:
#           n  n_chars         p         i max_pos max_pos_group  n_pos_group  \
# term_str
# 1         1        1  0.000001  19.49843      CD            CD            1
# 1790      1        4  0.000001  19.49843      CD            CD            1
# 1799      2        4  0.000003  18.49843      CD            CD            1
# 1801more  1        8  0.000001  19.49843      CD            CD            1
# 1807      1        4  0.000001  19.49843      CD            CD            1
#
#          cat_pos_group  n_pos cat_pos
# term_str
# 1                 {CD}      1    {CD}
# 1790              {CD}      1    {CD}
# 1799              {CD}      1    {CD}
# 1801more          {CD}      1    {CD}
# 1807              {CD}      1    {CD}

# %%
# add stopwords

sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1

VOCAB['stop'] = VOCAB.index.map(sw.dummy)
VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')

VOCAB[VOCAB.stop == 1].sample(10)
# Out:
#                n  n_chars         p          i max_pos max_pos_group  \
# term_str
# between      375        7  0.000506  10.947684      IN            IN
# or          1511        2  0.002040   8.937143      CC            CC
# ours          21        4  0.000028  15.106113      NN            NN
# had         7743        3  0.010454   6.579754     VBD            VB
# against      543        7  0.000733  10.413622      IN            IN
# will        1947        4  0.002629   8.571393      MD            MD
# him         4161        3  0.005618   7.475716     PRP            PR
# ourselves     56        9  0.000076  13.691076     PRP            NN
# yours         82        5  0.000111  13.140878      NN            NN
# to         22828        2  0.030822   5.019914      TO            TO
#
#            n_pos_group                     cat_pos_group  n_pos  \
# term_str
# between              2                          {NN, IN}      3
# or                   6          {IN, CC, RB, JJ, RP, NN}      7
# ours                 5              {IN, PR, VB, JJ, NN}      7
# had                  4                  {JJ, NN, RB, VB}     10
# against              3                      {NN, IN, VB}      7
# will                 8  {WP, IN, MD, VB, RB, WD, JJ, NN}     13
# him                  8  {CD, VB, PR, RB, RP, JJ, PD, NN}     16
# ourselves            7      {IN, MD, VB, PR, JJ, RP, NN}      9
# yours                6          {CD, PR, RB, VB, JJ, NN}      9
# to                   8  {FW, TO, IN, VB, RB, JJ, RP, NN}     10
#
#                                                      cat_pos  stop
# term_str
# between                                        {NNP, NN, IN}     1
# or                             {IN, CC, RB, JJ, RP, NN, NNP}     1
# ours                       {VBN, PRP, IN, JJR, NNS, NN, NNP}     1
# had           {VBN, VBZ, VBD, VBP, NNS, VB, RB, JJ, NN, NNP}     1
# against                     {VBN, IN, VBP, NNS, VB, NN, NNP}     1
# will       {WDT, VBZ, VBD, WP, VBP, IN, NNS, MD, VB, RB, ...     1
# him        {VBN, VBZ, VBD, PRP, PDT, RBR, VBP, JJR, NNS, ...     1
# ourselves            {VBZ, PRP, IN, NNS, MD, VB, JJ, RP, NN}     1
# yours               {VBZ, PRP, NNS, CD, VB, RB, JJ, NN, NNP}     1
# to                {FW, TO, IN, NNS, RB, VB, JJ, RP, NN, NNP}     1

# %%
# stemming

from nltk.stem.porter import PorterStemmer
stemmer1 = PorterStemmer()
VOCAB['stem_porter'] = VOCAB.apply(lambda x: stemmer1.stem(x.name), 1)

from nltk.stem.snowball import SnowballStemmer
stemmer2 = SnowballStemmer("english")
VOCAB['stem_snowball'] = VOCAB.apply(lambda x: stemmer2.stem(x.name), 1)

from nltk.stem.lancaster import LancasterStemmer
stemmer3 = LancasterStemmer()
VOCAB['stem_lancaster'] = VOCAB.apply(lambda x: stemmer3.stem(x.name), 1)

# %%
VOCAB.sample(10)
# Out:
#              n  n_chars         p          i max_pos max_pos_group  \
# term_str
# stared      20        6  0.000027  15.176502     VBD            VB
# chapbut      1        7  0.000001  19.498430      NN            NN
# cushioned    1        9  0.000001  19.498430      JJ            JJ
# orthoptera   2       10  0.000003  18.498430      NN            NN
# festoons     1        8  0.000001  19.498430     NNS            NN
# allthan      1        7  0.000001  19.498430      RP            RP
# contrived    6        9  0.000008  16.913468     VBN            VB
# meperhaps    1        9  0.000001  19.498430      VB            VB
# ceiled       1        6  0.000001  19.498430      JJ            JJ
# unforeseen   3       10  0.000004  17.913468      JJ            JJ
#
#             n_pos_group cat_pos_group  n_pos     cat_pos  stop stem_porter  \
# term_str
# stared                1          {VB}      2  {VBN, VBD}     0       stare
# chapbut               1          {NN}      1        {NN}     0     chapbut
# cushioned             1          {JJ}      1        {JJ}     0     cushion
# orthoptera            1          {NN}      1        {NN}     0  orthoptera
# festoons              1          {NN}      1       {NNS}     0     festoon
# allthan               1          {RP}      1        {RP}     0     allthan
# contrived             1          {VB}      1       {VBN}     0     contriv
# meperhaps             1          {VB}      1        {VB}     0    meperhap
# ceiled                1          {JJ}      1        {JJ}     0        ceil
# unforeseen            1          {JJ}      1        {JJ}     0  unforeseen
#
#            stem_snowball stem_lancaster
# term_str
# stared             stare           star
# chapbut          chapbut        chapbut
# cushioned        cushion           cush
# orthoptera    orthoptera      orthopter
# festoons         festoon        festoon
# allthan          allthan          allth
# contrived        contriv           cont
# meperhaps       meperhap       meperhap
# ceiled              ceil           ceil
# unforeseen    unforeseen     unforeseen

# %% [markdown]
# I chose to include the Snowball and Lancaster stems as well, since they will be used in just a moment answering questions 4 and 5. But they were not explicitly required as part of the VOCAB table. I believe that my LIB, CORPUS, and VOCAB tables all have the required features.

# %% [markdown]
# ## Part 2: Answering the Questions
#
# ### Question 1: *Middlemarch* chunking pattern

# %%
LIB.loc[145, "chap_regex"]
# Out:
# '^(?:PRELUDE|CHAPTER|FINALE)'

# %% [markdown]
# All the chapter headers were in all caps, and there was no Table of Contents, so this was very simple. I used as a template the pattern used for Melville's *Moby Dick*. I probably could have just had all caps as my criteria, but this is more specific.

# %% [markdown]
# ### Question 2: Title of Book with Most Tokens

# %%
LIB.sort_values('book_len', ascending=False)
# Out:
#                                           source_file_path         author  \
# book_id
# 145      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 507      /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
# 6688     /home/cwp5xyj/Documents/MSDS/DS5001/data/eliot...  ELIOT, GEORGE
#
#                          title                                chap_regex  \
# book_id
# 145                MIDDLEMARCH               ^(?:PRELUDE|CHAPTER|FINALE)
# 507                  ADAM BEDE  ^(?:Chapter\s+[IVXLCM]+|Epilogue)\.?\s*$
# 6688     THE MILL ON THE FLOSS            ^\s*Chapter\s+[IVXLCM]+\.?\s*$
#
#          book_len  n_chaps
# book_id
# 145        317805       88
# 507        215403       56
# 6688       207461       58

# %%
# to be fancy
LIB.sort_values('book_len', ascending=False).head(1).title.values[0]
# Out:
# 'MIDDLEMARCH'

# %% [markdown]
# The book with the most tokens is *Middlemarch*, which makes sense because it also has the most chapters.

# %% [markdown]
# ### Question 3: How many chapters in *Middlemarch*

# %%
LIB.sort_values('book_len', ascending=False).head(1).n_chaps.values[0]
# Out:
# 88

# %% [markdown]
# *Middlemarch* has 88 chapters. Or rather, 86 with a "Prelude" and a "Finale", for 88 chapter-level chunks.

# %% [markdown]
# ### Question 4: Which Stemmer is Most Aggressive?

# %%
# this is gonna involve a groupby right

len(VOCAB.groupby('stem_porter'))
# Out:
# 17546

# %%
len(VOCAB.groupby('stem_snowball'))
# Out:
# 17209

# %%
len(VOCAB.groupby('stem_lancaster'))
# Out:
# 14618

# %%
# just for context
len(VOCAB)
# Out:
# 26351

# %%
VOCAB.sample(20)
# Out:
#                  n  n_chars         p          i max_pos max_pos_group  \
# term_str
# hanged          12        6  0.000016  15.913468     VBN            VB
# electioneering   3       14  0.000004  17.913468     VBG            VB
# forsaken        19        8  0.000026  15.250503     VBN            VB
# clapping         5        8  0.000007  17.176502     VBG            VB
# hassock          1        7  0.000001  19.498430      NN            NN
# worritin         1        8  0.000001  19.498430      NN            NN
# wastes           1        6  0.000001  19.498430     VBZ            VB
# distributes      1       11  0.000001  19.498430     VBZ            VB
# motherknew       1       10  0.000001  19.498430      FW            FW
# davy             4        4  0.000005  17.498430     NNP            NN
# tied            17        4  0.000023  15.410968     VBN            VB
# poke             4        4  0.000005  17.498430      NN            VB
# keckan           1        6  0.000001  19.498430     NNP            NN
# dates            1        5  0.000001  19.498430      NN            NN
# linens           1        6  0.000001  19.498430      NN            NN
# positioni        1        9  0.000001  19.498430      NN            NN
# exorcising       1       10  0.000001  19.498430     VBG            VB
# prenticei        1        9  0.000001  19.498430      JJ            JJ
# helpsince        1        9  0.000001  19.498430      NN            NN
# joyous          11        6  0.000015  16.038999      JJ            JJ
#
#                 n_pos_group cat_pos_group  n_pos             cat_pos  stop  \
# term_str
# hanged                    3  {JJ, NN, VB}      3       {VBN, JJ, NN}     0
# electioneering            2      {NN, VB}      2           {VBG, NN}     0
# forsaken                  3  {JJ, NN, VB}      4  {VBN, JJ, NN, VBZ}     0
# clapping                  1          {VB}      1               {VBG}     0
# hassock                   1          {NN}      1                {NN}     0
# worritin                  1          {NN}      1                {NN}     0
# wastes                    1          {VB}      1               {VBZ}     0
# distributes               1          {VB}      1               {VBZ}     0
# motherknew                1          {FW}      1                {FW}     0
# davy                      1          {NN}      1               {NNP}     0
# tied                      2      {NN, VB}      3      {VBN, VBD, NN}     0
# poke                      2      {NN, VB}      3       {VBD, NN, VB}     0
# keckan                    1          {NN}      1               {NNP}     0
# dates                     1          {NN}      1                {NN}     0
# linens                    1          {NN}      1                {NN}     0
# positioni                 1          {NN}      1                {NN}     0
# exorcising                1          {VB}      1               {VBG}     0
# prenticei                 1          {JJ}      1                {JJ}     0
# helpsince                 1          {NN}      1                {NN}     0
# joyous                    1          {JJ}      1                {JJ}     0
#
#                stem_porter stem_snowball stem_lancaster
# term_str
# hanged                hang          hang           hang
# electioneering    election      election          elect
# forsaken          forsaken      forsaken         forsak
# clapping              clap          clap           clap
# hassock            hassock       hassock        hassock
# worritin          worritin      worritin       worritin
# wastes                wast          wast           wast
# distributes      distribut     distribut      distribut
# motherknew      motherknew    motherknew     motherknew
# davy                  davi          davi           davy
# tied                   tie           tie           tied
# poke                  poke          poke            pok
# keckan              keckan        keckan           keck
# dates                 date          date            dat
# linens               linen         linen            lin
# positioni        positioni     positioni       position
# exorcising         exorcis       exorcis          exorc
# prenticei        prenticei     prenticei       prentice
# helpsince         helpsinc      helpsinc       helpsint
# joyous               joyou        joyous            joy

# %% [markdown]
# The most aggressive stemmer is the Lancaster stemmer, which makes sense, because the above visual inspection of the DataFrame shows that Lancaster seems to generally have shorter stems.

# %% [markdown]
# ### Question 5: Lancaster stem with most associated terms

# %% [markdown]
# I am operating under the assumption that this question wants the number of different terms, not the total number of terms in the corpus. Would probably be like "and" or something otherwise. Not as interesting.

# %%
VOCAB['stem_lancaster'].value_counts().head(1)
# Out:
# stem_lancaster
# cont    34
# Name: count, dtype: int64

# %% [markdown]
# The Lancaster stem with the most associated terms is "cont", with 34 different associated terms.
